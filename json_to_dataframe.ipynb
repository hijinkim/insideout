# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/My\ Drive/Colab\ Notebooks/insideout/dataset/img9500.zip

# %%
# !unzip /content/drive/My\ Drive/Colab\ Notebooks/insideout/dataset/json9500.zip

# %%
import json
import pandas as pd

# %%
import glob

path = 'json/*'
json_list = glob.glob(path) # get json file name list

# %%
result = []

for j_file in json_list:
  with open(j_file) as f:
    json_data = json.load(f)
    label = list(json_data['flags'].values())
    img_path = json_data['imagePath']
    img_path = img_path.replace('.png', '')
    label.append(img_path)

  result.append(label)
print(result)
# Out:
# [[False, False, False, True, False, False, False, '2841'], [False, False, False, True, False, False, False, '450'], [False, False, False, True, False, False, False, '9202'], [False, False, False, True, False, False, False, '9052'], [True, True, False, True, False, False, False, '6689'], [False, False, False, True, False, False, '4496'], [False, True, False, True, False, False, '5028'], [True, True, False, True, False, False, False, '6723'], [False, True, False, True, False, False, False, '9898'], [False, False, False, True, False, False, False, '1927'], [False, False, False, True, True, False, False, '3610'], [False, False, False, True, False, False, False, '1783'], [False, False, False, True, False, False, '5587'], [True, False, False, True, False, False, False, '7287'], [True, False, False, True, False, False, False, '7256'], [False, False, False, True, False, False, '5495'], [False, False, False, True, False, False, '4888'], [False, False, False, True, False, False, False, '3849'], [False, False, False, True, False, False, '4644'], [False, False, False, True, False, False, False, '2184'], [False, False, False, True, False, False, False, '8808'], [False, True, False, True, False, False, False, '9558'], [True, True, False, True, True, False, False, '7194'], [False, False, False, True, False, False, False, '942'], [True, True, False, True, False, False, False, '6184'], [False, False, False, True, False, False, False, '798'], [False, False, False, True, False, False, False, '1115'], [False, False, False, True, False, False, False, '2392'], [False, False, False, True, False, False, False, '9329'], [True, True, False, True, False, False, False, '6871'], [False, False, False, True, False, False, False, '9286'], [False, False, False, True, False, False, False, '2406'], [True, True, False, True, False, False, False, '6214'], [False, False, False, True, False, False, False, '1067'], [False, False, False, True, False, False, '4511'], [False, False, False, True, False, False, False, '1774'], [True, True, False, True, False, False, False, '6303'], [False, False, False, True, False, False, False, '2673'], [True, False, False, True, False, False, False, '7348'], [False, False, False, True, False, False, False, '2806'], [False, False, False, True, False, False, False, '1253'], [False, False, False, True, False, False, False, '72'], [False, False, False, True, False, False, False, '1834'], [False, False, False, True, False, False, False, '2742'], [False, False, False, True, False, False, '5198'], [False, False, False, True, False, True, '4518'], [False, False, False, True, False, False, '5149'], [False, False, False, True, False, False, False, '858'], [False, False, False, True, False, False, '5629'], [False, False, False, True, False, False, '5379'], [False, True, False, True, False, False, False, '1976'], [False, True, False, True, False, False, '4433'], [False, False, False, True, False, False, False, '8433'], [False, False, False, True, False, False, False, '2302'], [False, False, False, True, False, False, False, '8921'], [False, True, False, True, False, False, False, '10029'], [False, False, False, True, False, False, False, '9528'], [False, False, False, True, False, False, '4699'], [False, False, False, False, False, False, True, '7006'], [False, False, False, True, False, False, False, '1108'], [False, True, False, True, False, False, False, '10224'], [False, False, False, True, False, False, False, '9219'], [False, False, False, True, False, False, False, '3160'], [False, False, False, True, False, True, '5458'], [False, True, False, True, False, False, False, '10241'], [False, True, False, True, False, False, False, '8107'], [False, False, False, True, False, False, False, '3936'], [True, True, False, True, False, False, False, '6352'], [False, False, False, True, False, False, False, '3829'], [False, False, False, True, False, False, '4292'], [False, False, False, True, False, False, False, '9078'], [False, True, False, True, F ...

# %%
col = json_data['flags'].keys()
col = list(col)
col.append('img_path')
col
# Out:
# ['root', 'branch', 'fruit', 'leaves', 'knot', 'willow', 'keyhole', 'img_path']

# %%
df = pd.DataFrame(data=result, columns=col)

# %%
df
# Out:
#        root  branch  fruit  leaves   knot  willow keyhole img_path
# 0     False   False  False    True  False   False   False     2841
# 1     False   False  False    True  False   False   False      450
# 2     False   False  False    True  False   False   False     9202
# 3     False   False  False    True  False   False   False     9052
# 4      True    True  False    True  False   False   False     6689
# ...     ...     ...    ...     ...    ...     ...     ...      ...
# 9508  False   False  False    True  False   False   False     3785
# 9509   True    True  False    True  False   False   False     7106
# 9510  False   False  False    True  False   False   False    10118
# 9511  False   False  False    True  False   False   False     8176
# 9512  False   False  False    True  False   False   False     8156
#
# [9513 rows x 8 columns]

# %%
df1 = df.set_index('img_path')

# %%
df1.sort_index()
# Out:
#            root  branch  fruit  leaves   knot  willow keyhole
# img_path
# 0         False   False  False    True  False   False   False
# 1         False    True  False    True  False   False   False
# 10        False   False  False    True  False   False   False
# 100       False   False  False    True  False   False   False
# 10000     False   False  False    True  False   False   False
# ...         ...     ...    ...     ...    ...     ...     ...
# NaN       False   False  False    True  False   False    4695
# NaN       False   False  False    True  False   False    5474
# NaN       False    True  False    True  False   False    4890
# NaN       False   False  False    True  False   False    4904
# NaN       False   False  False    True  False   False    4302
#
# [9513 rows x 7 columns]

# %%
without_nan = df.dropna(axis=0)

# %%
without_nan = without_nan.sort_values('img_path')

# %%
without_nan
# Out:
#        root  branch  fruit  leaves   knot  willow keyhole img_path
# 266   False   False  False    True  False   False   False        0
# 6191  False    True  False    True  False   False   False        1
# 6965  False   False  False    True  False   False   False       10
# 5617  False   False  False    True  False   False   False      100
# 987   False   False  False    True  False   False   False    10000
# ...     ...     ...    ...     ...    ...     ...     ...      ...
# 6551  False   False  False    True  False   False   False     9995
# 172   False   False  False    True  False   False   False     9996
# 4801   True   False  False    True  False   False   False     9997
# 8104  False   False  False    True  False   False   False     9998
# 7030  False   False  False    True  False   False   False     9999
#
# [7556 rows x 8 columns]

# %%
without_nan.to_excel('tree_label.xlsx')
